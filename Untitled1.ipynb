# %%
import requests
import pandas as pd
from io import StringIO

# Matomo API URL and parameters
url = "https://YOUR_MATOMO_DOMAIN/index.php"
params = {
    "module": "API",
    "method": "Live.getLastVisitsDetails",
    "idSite": "YOUR_SITE_ID",
    "period": "range",
    "date": "last10",
    "format": "csv",
    "token_auth": "YOUR_API_TOKEN"
}

# Fetch data from Matomo API
response = requests.get(url, params=params)
if response.status_code == 200:
    # Read the CSV data into a pandas DataFrame
    csv_data = response.text
    data = pd.read_csv(StringIO(csv_data))
    print(data)  # Process DataFrame
else:
    print(f"Failed to fetch data: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File C:\ProgramData\anaconda3\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
# ...

# %%
import requests
import pandas as pd
from io import StringIO

# Matomo API URL and parameters
url = "https://YOUR_MATOMO_DOMAIN/index.php"
params = {
    "module": "API",
    "method": "Live.getLastVisitsDetails",
    "idSite": "YOUR_SITE_ID",
    "period": "range",
    "date": "last10",
    "format": "csv",
    "token_auth": "YOUR_API_TOKEN"
}

# Fetch data from Matomo API
response = requests.get(url, params=params)
if response.status_code == 200:
    # Read the CSV data into a pandas DataFrame
    csv_data = response.text
    data = pd.read_csv(StringIO(csv_data))
    print(data)  # Process DataFrame
else:
    print(f"Failed to fetch data: {response.status_code}")

# %%
import requests
import pandas as pd
from io import StringIO
import psycopg2
from sqlalchemy import create_engine

# Constants
MATOMO_URL = "https://YOUR_MATOMO_DOMAIN/index.php"
ID_SITE = "YOUR_SITE_ID"
TOKEN_AUTH = "YOUR_API_TOKEN"
DB_CONNECTION_STRING = "postgresql://username:password@localhost:5432/mydatabase"

# Fetch data from Matomo API
params = {
    "module": "API",
    "method": "Live.getLastVisitsDetails",
    "idSite": ID_SITE,
    "period": "range",
    "date": "last10",
    "format": "csv",
    "token_auth": TOKEN_AUTH
}

response = requests.get(MATOMO_URL, params=params)
if response.status_code == 200:
    csv_data = response.text
    data = pd.read_csv(StringIO(csv_data))
    
    # Create a database connection using SQLAlchemy
    engine = create_engine(DB_CONNECTION_STRING)
    
    # Load data into a PostgreSQL table
    data.to_sql('matomo_last_visits', engine, if_exists='replace', index=False)
    print("Data loaded successfully into the database.")
else:
    print(f"Failed to fetch data: {response.status_code}")

# %%
import requests

# Base URL of the Matomo API
url = "https://caansoft.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=2&period=day&date=yesterday&format=json&token_auth=f08a340ccbae7c83d56ff1e81a3384d9&filter_limit=100"


# Making a GET request
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Print the response as JSON
    data = response.json()
    print(data)
else:
    print(f"Request failed with status code: {response.status_code}")

# %%
import requests
import pandas as pd

# Matomo API URL and parameters
url = "https://caansoft.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=2&period=day&date=yesterday&format=json&token_auth=f08a340ccbae7c83d56ff1e81a3384d9&filter_limit=100"

# File path to save CSV
csv_file_path = r'E:\matomo_visits.csv'  # Change this path as needed

# Making a GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON data
    data = response.json()

    # Convert JSON data to DataFrame
    df = pd.json_normalize(data)

    # Convert all columns to string to enforce VARCHAR(255)
    df = df.astype(str)

    # Save DataFrame to CSV
    df.to_csv(csv_file_path, index=False)

    print("Data exported to CSV successfully!")
else:
    print(f"Request failed with status code: {response.status_code}")

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

# Matomo API URL and parameters
url = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=Tsv&token_auth=anonymous&translateColumnNames=1"

# Database connection details
username = 'postgres'
password = 'Sharjeel'
host = 'localhost'  # or your PostgreSQL server address
port = '5432'  # default PostgreSQL port
database = 'Pharma'

# Create a SQLAlchemy engine instance
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database}')

# Making a GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON data
    data = response.json()

    # Convert JSON data to DataFrame
    df = pd.json_normalize(data)

    # Convert all columns to string to enforce VARCHAR(255)
    df = df.astype(str)

    # Create a table dynamically based on DataFrame and insert data
    df.to_sql('matomo_visits', engine, if_exists='replace', index=False)

    print("Data imported into database successfully!")
else:
    print(f"Request failed with status code: {response.status_code}")

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine
from io import StringIO

# CSV API URL
url = "https://example.com/data.csv"  # Replace with your actual CSV URL

# Database connection details
username = 'postgres'
password = 'Sharjeel'
host = 'localhost'  # or your PostgreSQL server address
port = '5432'  # default PostgreSQL port
database = 'Pharma'

# Create a SQLAlchemy engine instance
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database}')

# Making a GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the CSV data
    csv_data = StringIO(response.text)
    df = pd.read_csv(csv_data)

    # Convert all columns to string to enforce VARCHAR(255)
    df = df.astype(str)

    # Create a table dynamically based on DataFrame and insert data
    df.to_sql('matomo_visits', engine, if_exists='replace', index=False)

    print("Data imported into database successfully!")
else:
    print(f"Request failed with status code: {response.status_code}")

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine
from io import StringIO

# CSV API URL
url = "https://example.com/data.csv"  # Replace with your actual CSV URL

# Database connection details
username = 'postgres'
password = 'Sharjeel'
host = 'localhost'
port = '5432'
database = 'Pharma'

# Create a SQLAlchemy engine instance
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database}')

# Making a GET request
try:
    response = requests.get(url)
    response.raise_for_status()  # Raise an HTTPError for bad responses (4xx and 5xx)

    # Parse the CSV data
    csv_data = StringIO(response.text)
    df = pd.read_csv(csv_data)

    # Convert all columns to string to enforce VARCHAR(255)
    df = df.astype(str)

    # Create a table dynamically based on DataFrame and insert data
    df.to_sql('matomo_visits', engine, if_exists='replace', index=False)

    print("Data imported into database successfully!")

except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")

except Exception as e:
    print(f"An error occurred: {e}")

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

# Matomo API URL
url = "https://your-matomo-domain/matomo/index.php?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=today&format=JSON&token_auth=your_token_auth"

# Database connection details
username = 'postgres'
password = 'Sharjeel'
host = 'localhost'  # or your PostgreSQL server address
port = '5432'  # default PostgreSQL port
database = 'Pharma'

# Create a SQLAlchemy engine instance
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database}')

# Making a GET request to fetch the JSON data
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON data
    json_data = response.json()

    # Flatten the JSON structure and convert to a DataFrame
    df = pd.json_normalize(json_data)

    # Convert all columns to string to enforce VARCHAR(255) or appropriate types
    df = df.astype(str)

    # Insert data into PostgreSQL, dynamically creating table based on DataFrame structure
    df.to_sql('matomo_visits', engine, if_exists='replace', index=False)

    print("JSON data imported into the database successfully!")
else:
    print(f"Request failed with status code: {response.status_code}")

# %%
import requests
import pandas as pd

# Replace 'your-matomo-domain' with your actual Matomo domain and 'your_token_auth' with your actual token
url = "https://analytics.example.com/matomo/index.php?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=today&format=csv&token_auth=your_token_auth"

# Make the request to fetch CSV data
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Save the CSV data to a file (optional)
    with open('matomo_data.csv', 'wb') as f:
        f.write(response.content)

    # Alternatively, read CSV directly into a Pandas DataFrame
    data = pd.read_csv(url)
    print(data.head())  # Display the first few rows of the DataFrame
else:
    print(f"Request failed with status code: {response.status_code}")

# %%
import requests
import pandas as pd
from io import StringIO
from sqlalchemy import create_engine

# Step 1: Fetch data from the API
url = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=Tsv&token_auth=anonymous&translateColumnNames=1"
response = requests.get(url)


if response.status_code == 200:
    
    df = pd.read_csv(StringIO(response.text), sep='\t')
    
    
    df_limited = df.iloc[:, :921] 
    
 
    username = 'postgres'
    password = 'Sharjeel'
    host = 'localhost'
    port = '5432'
    database = 'Pharma'

   
    engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')

    table_name = 'matomo_visits'
    df_limited.to_sql(table_name, engine, if_exists='replace', index=False)

    print(f"Data successfully uploaded to the '{table_name}' table in PostgreSQL.")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# %%
import requests
import pandas as pd
from io import StringIO
from sqlalchemy import create_engine
import re

# URL to fetch the data
url = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=Tsv&token_auth=anonymous&translateColumnNames=1"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Load the data into a DataFrame
    df = pd.read_csv(StringIO(response.text), sep='\t')

    # Define a regular expression pattern to match column names
    pattern = re.compile(r'\(actionDetails \d+\)')

    # Filter columns to include only those matching the pattern
    filtered_columns = [column for column in df.columns if pattern.search(column)]

    # Limit the number of columns to 1600 if there are more
    if len(filtered_columns) > 1600:
        filtered_columns = filtered_columns[:1600]

    # Select the filtered columns from the DataFrame
    df_filtered = df[filtered_columns]

    # Optional: Print the list of found columns
    # print(f"Filtered columns: {filtered_columns}")

    # Database connection settings
    username = 'postgres'
    password = 'Sharjeel'
    host = 'localhost'
    port = '5432'
    database = 'Pharma'

    # Create the database connection engine
    engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')
    
    # Specify the table name
    table_name = 'matomo_table'
    
    # Upload the DataFrame to PostgreSQL
    df_filtered.to_sql(table_name, engine, if_exists='replace', index=False)

    print(f"Data successfully uploaded to the '{table_name}' table in PostgreSQL.")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine
import re

# URL to fetch the data
connect = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=Tsv&token_auth=anonymous&translateColumnNames=1"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Load the data into a DataFrame
    df = pd.read_csv(create_engine(connect), sep='\t')

    # Define a regular expression pattern to match column names
    pattern = re.compile(r'\(actionDetails \d+\)')

    # Filter columns to include only those matching the pattern
    filtered_columns = [column for column in df.columns if pattern.search(column)]

    # Limit the number of columns to 1600 if there are more
    if len(filtered_columns) > 1600:
        filtered_columns = filtered_columns[:1600]

    # Select the filtered columns from the DataFrame
    df_filtered = df[filtered_columns]

    # Optional: Print the list of found columns
    # print(f"Filtered columns: {filtered_columns}")

    # Database connection settings
    username = 'postgres'
    password = 'Sharjeel'
    host = 'localhost'
    port = '5432'
    database = 'Pharma'

    # Create the database connection engine
    engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')
    
    # Specify the table name
    table_name = 'matomo_table'
    
    # Upload the DataFrame to PostgreSQL
    df_filtered.to_sql(table_name, engine, if_exists='replace', index=False)

    print(f"Data successfully uploaded to the '{table_name}' table in PostgreSQL.")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine
import re


url = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=Tsv&token_auth=anonymous&translateColumnNames=1"
response = requests.get(url)
param_dic = {
    "host"      : "localhost",
    "database"  : "Pharma",
    "user"      : "myuser",
    "password"  : "Sharjeel"
}
def to_alchemy(df):
    """
    Using a dummy table to test this call library
    """
    engine = create_engine(connect)
    df.to_sql(
        'test_table', 
        con=engine, 
        index=False, 
        if_exists='replace'
    )
    print("to_sql() done (sqlalchemy)")

# %%
# Here you want to change your database, username & password according to your own values
param_dic = {
    "host"      : "localhost",
    "database"  : "Pharma",
    "user"      : "postgres",
    "password"  : "Sharjeel"
}

import pandas as pd
csv_file = "E:\Store_Data.csv"
df = pd.read_csv(csv_file)
df = df.rename(columns={
    "Source": "source", 
    "Date": "datetime",
    "Mean": "mean_temp"
})


import os
import psycopg2
import numpy as np
import psycopg2.extras as extras
from io import StringIO

def copy_from_stringio(conn, df, storesales):
    """
    Here we are going save the dataframe in memory 
    and use copy_from() to copy it to the table
    """
    # save dataframe to an in memory buffer
    buffer = StringIO()
    df.to_csv(buffer, index_label='id', header=False)
    buffer.seek(0)
    
    cursor = conn.cursor()
    try:
        cursor.copy_from(buffer, table, sep=",")
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("copy_from_stringio() done")
    cursor.close()

# %%
import requests
import pandas as pd
from io import StringIO
from sqlalchemy import create_engine
import re

# URL to fetch the data
url = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=Tsv&token_auth=anonymous&translateColumnNames=1"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    
    def copy_from_stringio(conn, df, person):
        
   
    # save dataframe to an in memory buffer
        buffer = StringIO()
        df.to_csv(buffer, index_label='id', header=False)
        buffer.seek(0)
    
    cursor = conn.cursor()
    try:
        cursor.copy_from(buffer, person, sep=",")
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("copy_from_stringio() done")
    cursor.close()

    # Define a regular expression pattern to match column names
    pattern = re.compile(r'\(actionDetails \d+\)')

    # Filter columns to include only those matching the pattern
    filtered_columns = [column for column in df.columns if pattern.search(column)]

    # Limit the number of columns to 1600 if there are more
    if len(filtered_columns) > 1600:
        filtered_columns = filtered_columns[:1600]

    # Select the filtered columns from the DataFrame
    df_filtered = df[filtered_columns]

    # Optional: Print the list of found columns
    # print(f"Filtered columns: {filtered_columns}")

    # Database connection settings
    username = 'postgres'
    password = 'Sharjeel'
    host = 'localhost'
    port = '5432'
    database = 'Pharma'

    # Create the database connection engine
    engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')
    
    # Specify the table name
    table_name = 'person'
    
    # Upload the DataFrame to PostgreSQL
    df_filtered.to_sql(table_name, engine, if_exists='replace', index=False)

    print(f"Data successfully uploaded to the '{person}' table in PostgreSQL.")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# %%
import requests
import pandas as pd
from io import StringIO
from sqlalchemy import create_engine
import re

df_column = ["type (actionDetails 0)",
    "url (actionDetails 0)",
    "pageTitle (actionDetails 0)", 
    "pageIdAction (actionDetails 0)" 
        
    ]

def copy_from_stringio(conn, df, person):
    buffer = StringIO()
    df.to_csv(buffer, index_label='id', header=False)
    buffer.seek(0)

    cursor = conn.cursor()
    try:
        cursor.copy_from(buffer, table, sep=",")
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    

# URL to fetch the data
url = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=Tsv&token_auth=anonymous&translateColumnNames=1"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    pattern = re.compile(r'\(actionDetails \d+\)')
    filtered_columns = [column for column in df.columns if pattern.search(column)]

   
    if len(filtered_columns) > 1600:
        filtered_columns = filtered_columns[:1600]

    
    df_filtered = df[filtered_columns]
    
  

    # Optional: Print the list of found columns
    # print(f"Filtered columns: {filtered_columns}")

    # Database connection settings
    username = 'postgres'
    password = 'Sharjeel'
    host = 'localhost'
    port = '5432'
    database = 'Pharma'

    # Create the database connection engine
    engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')
    
    # Specify the table name
    table_name = 'person'
    
    # Upload the DataFrame to PostgreSQL
    df_filtered.to_sql(table_name, engine, if_exists='replace', index=False)

    print(f"Data successfully uploaded to the '{table_name}' table in PostgreSQL.")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# %%
import requests
import pandas as pd
from io import StringIO
from sqlalchemy import create_engine
import re

# URL to fetch the data
url = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=TSV&token_auth=anonymous"
response = requests.get(url)

df = pd.DataFrame(response)
df

# %%
df

# %%
import requests
import pandas as pd


# URL to fetch the data from
url = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=Tsv&token_auth=anonymous&translateColumnNames=1"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Read the TSV data into a DataFrame
    df = pd.read_csv(StringIO(response.text), sep='\t')
    
    # Save the DataFrame to an Excel file
    df.to_excel('datanew.xlsx', index=False)
    print("Data successfully saved to data.xlsx")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      11 # Check if the request was successful
#      12 if response.status_code == 200:
#      13     # Read the TSV data into a DataFrame
# ---> 14     df = pd.read_csv(StringIO(response.text), sep='\t')
#      16     # Save the DataFrame to an Excel file
#      17     df.to_excel('datanew.xlsx', index=False)
#
# NameError: name 'StringIO' is not defined

# %%
import requests
import pandas as pd
import re

# URL to fetch the data from
url = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=Tsv&token_auth=anonymous&translateColumnNames=1"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Read the TSV data into a DataFrame
    df = pd.read_csv(StringIO(response.text), sep='\t')
    required_columns = [
    "type (actionDetails 0)",
 "url (actionDetails 0)",
 "pageTitle (actionDetails 0)",
 "pageIdAction (actionDetails 0)"
      ]

#     #action_details_pattern = re.compile(r"^pageTitle \(actionDetails \d+\)$|^pageIdAction \(actionDetails \d+\)$")
#     action_details_pattern = re.compile(r"^pageTitle \(actionDetails [1-9]|10\)$|^pageIdAction \(actionDetails [1-9]|10\)$")

    df_columns = df.columns

    filtered_columns = [col for col in df_columns if col in required_columns]

    df_filtered = df[filtered_columns]

    
# copy_from_stringio(conn, df_filtered, 'yor column name')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 # Check if the request was successful
#      12 if response.status_code == 200:
#      13     # Read the TSV data into a DataFrame
# ---> 14     df = pd.read_csv(StringIO(response.text), sep='\t')
#      15     required_columns = [
#      16     "type (actionDetails 0)",
#      17  "url (actionDetails 0)",
#      18  "pageTitle (actionDetails 0)",
#      19  "pageIdAction (actionDetails 0)"
#      20       ]
#      22 #     #action_details_pattern = re.compile(r"^pageTitle \(actionDetails \d+\)$|^pageIdAction \(actionDetails \d+\)$")
#      23 #     action_details_pattern = re.compile(r"^pageTitle \(actionDetails [1-9]|10\)$|^pageIdAction \(actionDetails [1-9]|10\)$")
#
# NameError: name 'StringIO' is not defined

# %%
df_filtered
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_filtered
#
# NameError: name 'df_filtered' is not defined

# %%
import pandas as pd
import numpy as np
from io import StringIO
import psycopg2

def copy_from_stringio(conn, df, table):

    buffer = StringIO()
    df.to_csv(buffer, header=False, index=False, na_rep='') 
    buffer.seek(0)
    
    cursor = conn.cursor()

    try:
        cursor.copy_from(buffer, table, sep=",", null='') 
        conn.commit()
        print("copy_from_stringio() done")
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
    finally:
        cursor.close()

# %%
# copy_from_stringio(conn, df_filtered, 'person')

# %%
import requests
import pandas as pd
from io import StringIO
from sqlalchemy import create_engine
import re

df_column = ["type (actionDetails 0)",
    "url (actionDetails 0)",
    "pageTitle (actionDetails 0)", 
    "pageIdAction (actionDetails 0)" 
        
    ]

def copy_from_stringio(conn, df, person):
    buffer = StringIO()
    df.to_csv(buffer, index_label='id', header=False)
    buffer.seek(0)

    cursor = conn.cursor()
    try:
        cursor.copy_from(buffer, table, sep=",")
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    

# URL to fetch the data
url = "https://demo.matomo.cloud/?module=API&method=Live.getLastVisitsDetails&idSite=1&period=day&date=yesterday&format=Tsv&token_auth=anonymous&translateColumnNames=1"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Read the TSV data into a DataFrame
    df = pd.read_csv(StringIO(response.text), sep='\t')
    df_columns = df.columns

    filtered_columns = [col for col in df_columns if col in required_columns]

    df_filtered = df[filtered_columns]

    username = 'postgres'
    password = 'Sharjeel'
    host = 'localhost'
    port = '5432'
    database = 'Pharma'

    # Create the database connection engine
    engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')
    
    # Specify the table name
    table_name = 'person'
    
    # Upload the DataFrame to PostgreSQL
    df_filtered.to_sql(table_name, engine, if_exists='replace', index=False)

    print(f"Data successfully uploaded to the '{table_name}' table in PostgreSQL.")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 40
#      37 df = pd.read_csv(StringIO(response.text), sep='\t')
#      38 df_columns = df.columns
# ---> 40 filtered_columns = [col for col in df_columns if col in required_columns]
#      42 df_filtered = df[filtered_columns]
#      44 username = 'postgres'
#
# Cell In[1], line 40, in <listcomp>(.0)
#      37 df = pd.read_csv(StringIO(response.text), sep='\t')
#      38 df_columns = df.columns
# ---> 40 filtered_columns = [col for col in df_columns if col in required_columns]
#      42 df_filtered = df[filtered_columns]
#      44 username = 'postgres'
#
# NameError: name 'required_columns' is not defined
