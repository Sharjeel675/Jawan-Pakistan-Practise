# %%
import pandas as pd
import sqlite3 as sql

# %%
conn = sql.connect('factbook.db')
conn

# %%
q = "select * from sqlite_master"
pd.read_sql_query(q, conn)
# Out:
#     type             name         tbl_name  rootpage  \
# 0  table  sqlite_sequence  sqlite_sequence         3
# 1  table            facts            facts        47
# 2  table           cities           cities         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY...
# 2  CREATE TABLE cities (\n        id integer prim...

# %%
q = "select * from facts"
pd.read_sql_query(q, conn)
# Out:
#       id code            name       area  area_land  area_water    population  \
# 0      1   af     Afghanistan   652230.0   652230.0         0.0  3.256434e+07
# 1      2   al         Albania    28748.0    27398.0      1350.0  3.029278e+06
# 2      3   ag         Algeria  2381741.0  2381741.0         0.0  3.954217e+07
# 3      4   an         Andorra      468.0      468.0         0.0  8.558000e+04
# 4      5   ao          Angola  1246700.0  1246700.0         0.0  1.962535e+07
# ..   ...  ...             ...        ...        ...         ...           ...
# 256  257   zh  Atlantic Ocean        NaN        NaN         NaN           NaN
# 257  258   xo    Indian Ocean        NaN        NaN         NaN           NaN
# 258  259   zn   Pacific Ocean        NaN        NaN         NaN           NaN
# 259  260   oo  Southern Ocean        NaN        NaN         NaN           NaN
# 260  261   xx           World        NaN        NaN         NaN  7.256490e+09
#
# ...

# %%
q = "select * from cities"
pd.read_sql_query(q, conn)
# Out:
#       id          name  population  capital facts_id
# 0      1    Oranjestad       37000        1      216
# 1      2  Saint John'S       27000        1        6
# 2      3     Abu Dhabi      942000        1      184
# 3      4         Dubai     1978000        0      184
# 4      5       Sharjah      983000        0      184
# ..   ...           ...         ...      ...      ...
# 392  393       Mbabane       66000        1      167
# 393  394         Sanaa     2419000        1      193
# 394  395          Aden      784000        0      193
# 395  396        Lusaka     1802000        1      194
# 396  397        Harare     1542000        1      195
#
# [397 rows x 5 columns]

# %%
q = '''
select f.name Country_Name , c.name City_Name,c.population City_Population from facts f
inner join cities c
ON
f.id = c.facts_id
where c.capital == 1 OR c.population > 10000000
 '''
     
pd.read_sql_query(q, conn)
# Out:
#              Country_Name     City_Name  City_Population
# 0                   Aruba    Oranjestad            37000
# 1     Antigua and Barbuda  Saint John'S            27000
# 2    United Arab Emirates     Abu Dhabi           942000
# 3             Afghanistan         Kabul          3097000
# 4                 Algeria       Algiers          2916000
# ..                    ...           ...              ...
# 215                 Samoa          Apia            37000
# 216             Swaziland       Mbabane            66000
# 217                 Yemen         Sanaa          2419000
# 218                Zambia        Lusaka          1802000
# 219              Zimbabwe        Harare          1542000
#
# [220 rows x 3 columns]

# %%
q = '''
select f.name Country_Name,c.name City_Name from facts f
inner join cities c
ON
f.id = c.facts_id
where f.name IS 'United Arab Emirates'
 '''
     
pd.read_sql_query(q, conn)
# Out:
#            Country_Name  City_Name
# 0  United Arab Emirates  Abu Dhabi
# 1  United Arab Emirates      Dubai
# 2  United Arab Emirates    Sharjah

# %%
q = '''
select c.population Capital_Population from facts f
inner join cities c
ON
f.id = c.facts_id
where c.capital == 0 AND c.population > 10000000 
order by Capital_Population desc
limit 3

 '''
     
pd.read_sql_query(q, conn)
# Out:
#    Capital_Population
# 0            20352000
# 1            20208000
# 2            19924000
